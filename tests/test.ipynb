# %%
import numpy as np

# Stream CSV → binary bits
with open("C:\\Users\\umair\\Videos\\JOB - NASTP\\SATCOM\\Code\\bits_single_column.csv", "r") as f:
    bits = np.fromiter((int(line.strip()) for line in f), dtype=np.uint8)

bits.tofile("bits.bin")
